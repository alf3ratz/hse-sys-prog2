# %% [markdown]
# # Setup

# %%
# !pip install -q datasets
# !pip install -q evaluate
# !pip install -q sentencepiece
# !pip install -q transformers
# !pip install -q accelerate -U
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 7.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 1.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 2.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 40.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 57.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 46.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 1.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 1.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 2.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 3.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 4.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 3.7 MB/s eta 0:00:00

# %%
import copy
import datasets
import evaluate
import numpy as np
import pandas as pd
import seaborn as sns
import torch
torch.cuda.empty_cache()
import torch.nn as nn
import torch.optim as optim
import warnings

from dataclasses import dataclass
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from transformers import T5ForConditionalGeneration, AutoTokenizer, T5Config
from transformers import Trainer, TrainingArguments

# %%
tqdm.pandas()
warnings.filterwarnings("ignore", category=DeprecationWarning)

if torch.cuda.is_available():
    DEVICE = torch.device("cuda")
else:
    DEVICE = torch.device("cpu")
DEVICE
# Out:
# device(type='cuda')

# %%
MODEL_NAME = "t5-base"
SEED = 1234

torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %% [markdown]
# # Prepare Dataset

# %%
df_train_java = datasets.load_dataset(
    "code_x_glue_ct_code_to_text",
    "java",
    split="train")
df_valid_java = datasets.load_dataset(
    "code_x_glue_ct_code_to_text",
    "java",
    split="validation")
df_test_java = datasets.load_dataset(
    "code_x_glue_ct_code_to_text",
    "java",
    split="test")

df_train_java = pd.DataFrame({
    'nl': df_train_java['docstring'],
    'code': df_train_java['code'],
    "language": "java"
})
df_valid_java = pd.DataFrame({
    'nl': df_valid_java['docstring'],
    'code': df_valid_java['code'],
    "language": "java"
})
df_test_java = pd.DataFrame({
    'nl': df_test_java['docstring'],
    'code': df_test_java['code'],
    "language": "java"
})
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/26.7k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/141M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.25M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/9.38M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/164923 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/5183 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/10955 [00:00<?, ? examples/s]

# %%
df_train_go = datasets.load_dataset(
    "code_x_glue_ct_code_to_text",
    "go",
    split="train")
df_valid_go = datasets.load_dataset(
    "code_x_glue_ct_code_to_text",
    "go",
    split="validation")
df_test_go = datasets.load_dataset(
    "code_x_glue_ct_code_to_text",
    "go",
    split="test")

df_train_go = pd.DataFrame({
    'nl': df_train_go['docstring'],
    'code': df_train_go['code'],
    "language": "go"
})
df_valid_go = pd.DataFrame({
    'nl': df_valid_go['docstring'],
    'code': df_valid_go['code'],
    "language": "go"
})
df_test_go = pd.DataFrame({
    'nl': df_test_go['docstring'],
    'code': df_test_go['code'],
    "language": "go"
})
# Out:
# Downloading data:   0%|          | 0.00/112M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/4.29M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/5.43M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/167288 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/7325 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/8122 [00:00<?, ? examples/s]

# %%
df_train_java.head()
# Out:
#                                                   nl  \
# 0  Compare the supplied plaintext password to a h...
# 1  Attempt to detect the current platform.\n\n@re...
# 2  Gets the node meta data.\n\n@param key - the m...
# 3  Copies all node meta data from the other node ...
# 4  Sets the node meta data.\n\n@param key - the m...
#
#                                                 code language
# 0  public static boolean check(String passwd, Str...     java
# 1  public static Platform detect() throws Unsuppo...     java
# 2  public <T> T getNodeMetaData(Object key) {\n  ...     java
# 3  public void copyNodeMetaData(ASTNode other) {\...     java
# 4  public void setNodeMetaData(Object key, Object...     java

# %%
df_train_go.head()
# Out:
#                                                   nl  \
# 0  // getStringValue will return a quoted string ...
# 1  // getBoolValue will return a boolean and the ...
# 2  // getNumericalValue will return a numerical s...
# 3  // getNegativeNumber will return a negative nu...
# 4  // isEscaped will return whether or not the ch...
#
#                                                 code language
# 0  func getStringValue(b []rune) (int, error) {\n...       go
# 1  func getBoolValue(b []rune) (int, error) {\n\t...       go
# 2  func getNumericalValue(b []rune) (int, int, er...       go
# 3  func getNegativeNumber(b []rune) int {\n\tif b...       go
# 4  func isEscaped(value []rune, b rune) bool {\n\...       go

# %%
def add_java_slashes(a):
    return "// " + "\n// ".join(a.split("\n"))

# %%
df_train_java["nl"] = df_train_java["nl"].apply(add_java_slashes)
df_valid_java["nl"] = df_valid_java["nl"].apply(add_java_slashes)
df_test_java["nl"] = df_test_java["nl"].apply(add_java_slashes)
df_train_java.head()
# Out:
#                                                   nl  \
# 0  // Compare the supplied plaintext password to ...
# 1  // Attempt to detect the current platform.\n//...
# 2  // Gets the node meta data.\n// \n// @param ke...
# 3  // Copies all node meta data from the other no...
# 4  // Sets the node meta data.\n// \n// @param ke...
#
#                                                 code language
# 0  public static boolean check(String passwd, Str...     java
# 1  public static Platform detect() throws Unsuppo...     java
# 2  public <T> T getNodeMetaData(Object key) {\n  ...     java
# 3  public void copyNodeMetaData(ASTNode other) {\...     java
# 4  public void setNodeMetaData(Object key, Object...     java

# %%
df_train = df_train_java.append(df_train_go, ignore_index=True)
df_valid = df_valid_java.append(df_valid_go, ignore_index=True)
df_test = df_test_java.append(df_test_go, ignore_index=True)
# Out:
# <ipython-input-11-10c3ab1b794f>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_train = df_train_java.append(df_train_go, ignore_index=True)
# <ipython-input-11-10c3ab1b794f>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_valid = df_valid_java.append(df_valid_go, ignore_index=True)
# <ipython-input-11-10c3ab1b794f>:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_test = df_test_java.append(df_test_go, ignore_index=True)

# %%
df_train = df_train.head(5000)
df_valid = df_valid.head(5000)
df_test = df_test.head(5000)

# %%
df_valid
# Out:
#                                                    nl  \
# 0   // Copies the contents of this source to the g...
# 1   // Reads the contents of this source as a stri...
# 2   // Reads all the lines of this source as a lis...
# 3                            // buffer when possible.
# 4   // Returns a new CharBuffer identical to buf, ...
# 5   // Handle the case of underflow caused by need...
# 6   // Flips the buffer output buffer so we can st...
# 7   // Copies an iterable's elements into an array...
# 8   // Determines if the given iterable contains n...
# 9                       // Useful as a public method?
# 10  // Returns an Iterator that walks the specifie...
# 11  // Concats a varargs array of iterators withou...
# 12    // Clears the iterator using its remove method.
# 13  // Writes all the given bytes to this sink.\n/...
# 14  // Creates a CacheBuilderSpec from a string.\n...
# 15  // Returns a CacheBuilder configured according...
# 16  // Returns a joiner with the same behavior as ...
# 17  // okay since we have to copy the just-created...
# 18  // Returns a new immutable array containing th...
# 19  // Reads the next byte of data from the underl...
# 20  // Reads the specified bytes of data from the ...
# 21  // Stores the contents of a map in an output s...
# 22  // Stores the contents of a multiset in an out...
# 23  // Secret sauce for setting final fields; don'...
# 24  // Starts the stopwatch.\n// \n// @return this...
# 25  // Adds a number of occurrences of the specifi...
# 26       // Resizes the entries storage if necessary.
# 27  // Convert a byte array into an InetAddress.\n...
# 28  // Identify and mark the longest run of zeroes...
# 29  // Convert a list of hextets into a human-read...
#
#                                                  code language
# 0   @CanIgnoreReturnValue\n  public long copyTo(Ch...     java
# 1   public String read() throws IOException {\n   ...     java
# 2   public ImmutableList<String> readLines() throw...     java
# 3   @Override\n  public int read(byte[] b, int off...     java
# 4   private static CharBuffer grow(CharBuffer buf)...     java
# 5   private void readMoreChars() throws IOExceptio...     java
# 6   private void startDraining(boolean overflow) {...     java
# 7   @GwtIncompatible // Array.newInstance(Class, i...     java
# 8   public static boolean isEmpty(Iterable<?> iter...     java
# 9   static <T> Function<Iterable<? extends T>, Ite...     java
# 10  private static <T> Iterator<T> consumingForArr...     java
# 11  static <T> Iterator<T> concatNoDefensiveCopy(I...     java
# 12  static void clear(Iterator<?> iterator) {\n   ...     java
# 13  public void write(byte[] bytes) throws IOExcep...     java
# 14  public static CacheBuilderSpec parse(String ca...     java
# 15  CacheBuilder<Object, Object> toCacheBuilder() ...     java
# 16  public Joiner skipNulls() {\n    return new Jo...     java
# 17  public static ImmutableIntArray of(int first, ...     java
# 18  public ImmutableIntArray subArray(int startInd...     java
# 19  @Override\n  @CanIgnoreReturnValue\n  public i...     java
# 20  @Override\n  @CanIgnoreReturnValue\n  public i...     java
# 21  static <K, V> void writeMap(Map<K, V> map, Obj...     java
# 22  static <E> void writeMultiset(Multiset<E> mult...     java
# 23  static <T> FieldSetter<T> getFieldSetter(final...     java
# 24  @CanIgnoreReturnValue\n  public Stopwatch star...     java
# 25  @CanIgnoreReturnValue\n  @Override\n  public i...     java
# 26  private void resizeMeMaybe(int newSize) {\n   ...     java
# 27  private static InetAddress bytesToInetAddress(...     java
# 28  private static void compressLongestRunOfZeroes...     java
# 29  private static String hextetsToIPv6String(int[...     java

# %%
df_test
# Out:
#                                                    nl  \
# 0   // Makes sure the fast-path emits in order.\n/...
# 1   // Wraps an ObservableSource into an Observabl...
# 2   // Returns an Observable that emits the events...
# 3   // Child Observers will observe the events of ...
# 4   // Creates an UnicastProcessor with the given ...
# 5   // Creates an UnicastProcessor with the given ...
# 6   // Tries to subscribe to a possibly Callable s...
# 7   // Maps a scalar value into a Publisher and em...
# 8   // Removes all handlers and resets to default ...
# 9   // Wraps a CompletableSource into a Maybe.\n//...
# 10  // Wraps a SingleSource into a Maybe.\n// \n//...
# 11  // Retries at most times or until the predicat...
# 12  // Verifies if the object is not null and retu...
# 13  // Returns an identity function that simply re...
# 14  // Returns a Callable that returns the given v...
# 15  // Returns a Function that ignores its paramet...
# 16  // Returns a function that cast the incoming v...
# 17  // Creates an UnicastSubject with an internal ...
# 18  // Creates an UnicastSubject with the given in...
# 19  // Creates an UnicastSubject with the given in...
# 20  // Creates an UnicastSubject with an internal ...
# 21  // Block until the latch is counted down and r...
# 22  // Block until the latch is counted down and r...
# 23  // Block until the observer terminates and ret...
# 24  // Drain the queue but give up with an error i...
# 25  // Requests Long.MAX_VALUE if prefetch is nega...
# 26  // Signals the completion of the main sequence...
# 27  // Signals the given value and an onComplete i...
# 28  // Returns the contained value if this notific...
# 29  // Returns the container Throwable error if th...
#
#                                                  code language
# 0   protected final void fastPathOrderedEmit(U val...     java
# 1   @CheckReturnValue\n    @SchedulerSupport(Sched...     java
# 2   @CheckReturnValue\n    @SchedulerSupport(Sched...     java
# 3   public static <T> ConnectableObservable<T> obs...     java
# 4   @CheckReturnValue\n    @NonNull\n    public st...     java
# 5   @CheckReturnValue\n    @NonNull\n    public st...     java
# 6   @SuppressWarnings("unchecked")\n    public sta...     java
# 7   public static <T, U> Flowable<U> scalarXMap(fi...     java
# 8   public static void reset() {\n        setError...     java
# 9   @CheckReturnValue\n    @NonNull\n    @Schedule...     java
# 10  @CheckReturnValue\n    @NonNull\n    @Schedule...     java
# 11  @CheckReturnValue\n    @SchedulerSupport(Sched...     java
# 12  public static <T> T requireNonNull(T object, S...     java
# 13  @SuppressWarnings("unchecked")\n    public sta...     java
# 14  public static <T> Callable<T> justCallable(T v...     java
# 15  public static <T, U> Function<T, U> justFuncti...     java
# 16  public static <T, U> Function<T, U> castFuncti...     java
# 17  @CheckReturnValue\n    @NonNull\n    public st...     java
# 18  @CheckReturnValue\n    @NonNull\n    public st...     java
# 19  @CheckReturnValue\n    @NonNull\n    public st...     java
# 20  @CheckReturnValue\n    @NonNull\n    public st...     java
# 21  public Throwable blockingGetError() {\n       ...     java
# 22  public Throwable blockingGetError(long timeout...     java
# 23  public boolean blockingAwait(long timeout, Tim...     java
# 24  public static <T, U> void drainMaxLoop(SimpleP...     java
# 25  public static void request(Subscription s, int...     java
# 26  public static <T> void postComplete(Subscriber...     java
# 27  protected final void complete(R n) {\n        ...     java
# 28  @SuppressWarnings("unchecked")\n    @Nullable\...     java
# 29  @Nullable\n    public Throwable getError() {\n...     java

# %% [markdown]
# # Train

# %%
tokenizer_code = AutoTokenizer.from_pretrained(MODEL_NAME)
tokenizer_nl = AutoTokenizer.from_pretrained(MODEL_NAME)

# %%
class Code2TextDataset(Dataset):
    def __init__(self, df):
        self.df = df

    def __len__(self):
        return len(self.df)

    def __getitem__(self, i):
        code = self.df["language"].iloc[i] \
            + " docstring: " + self.df['code'].iloc[i]
        nl = self.df['nl'].iloc[i]

        code_tokenized = tokenizer_code(
            code,
            padding="max_length",
            max_length=64,
            truncation=True)
        code_input_ids = code_tokenized.input_ids
        code_attention = code_tokenized.attention_mask

        nl_tokenized = tokenizer_nl(
            nl,
            padding="max_length",
            max_length=64,
            truncation=True)
        nl_input_ids = nl_tokenized.input_ids

        return {
            "input_ids": code_input_ids,
            "labels": nl_input_ids,
            "attention_mask": code_attention
        }

# %%
# TODO: Implement this and add as parameter in Trainer
def compute_metrics(eval_pred):
    print(eval_pred)
    logits, labels = eval_pred
    return 1

# %%
model = T5ForConditionalGeneration.from_pretrained(MODEL_NAME)
#model.cuda()

training_args = TrainingArguments(
    output_dir="code2nl",
    evaluation_strategy="epoch",
    num_train_epochs=10,
    per_device_train_batch_size=128,
    per_device_eval_batch_size=128,
)

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=Code2TextDataset(df_train),
    eval_dataset=Code2TextDataset(df_valid),
)
trainer.train()
# Out:
# /usr/local/lib/python3.10/dist-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches', 'even_batches', 'use_seedable_sampler']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False, even_batches=True, use_seedable_sampler=True)
#   warnings.warn(
#     <div>
#
#       <progress value='10' max='10' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10/10 00:10, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>No log</td>
#       <td>9.174901</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>No log</td>
#       <td>8.544143</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>No log</td>
#       <td>8.106703</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>No log</td>
#       <td>7.558287</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>No log</td>
#       <td>7.102834</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>No log</td>
#       <td>6.761730</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>No log</td>
#       <td>6.506609</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>No log</td>
#       <td>6.338633</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>No log</td>
#       <td>6.228750</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>No log</td>
#       <td>6.175273</td>
#     </tr>
#   </tbody>
# </table><p>
# TrainOutput(global_step=10, training_loss=5.397150039672852, metrics={'train_runtime': 11.7547, 'train_samples_per_second': 25.522, 'train_steps_per_second': 0.851, 'total_flos': 22835920896000.0, 'train_loss': 5.397150039672852, 'epoch': 10.0})

# %% [markdown]
# # Generate

# %%
text = \
    'java docstring: void printMessage(String message) { int x = 2; int y = 3; System.out.println(x+y) }'

input_ids = tokenizer_code(text, return_tensors="pt").input_ids.cuda()
outputs = model.generate(input_ids)

print("\n//".join(tokenizer_nl.decode(outputs[0], skip_special_tokens=True)
    .split("//"))[1:])
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1178: UserWarning: Using the model-agnostic default `max_length` (=20) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# ava docstring: void printMessage(String message)  int
